# %%
import json
import pandas as pd
import io
from random import randint
import webbrowser
import numpy as np
import matplotlib.pyplot as plt
from random import seed
from random import sample
import requests

# %%
fields = ["file_name",
          "cases.case_id",
          "cases.primary_site",
          "cases.diagnoses.primary_diagnosis",
          "cases.project.disease_type",
          "cases.samples.is_ffpe",
          "md5sum",
          "file_size",
          "state",
          "cases.diagnoses.tissue_or_organ_of_origin",
          "cases.diagnoses.morphology",
          "experimental_strategy"]

# %%
fields = ["file_name",
          "cases.case_id",
          "cases.primary_site",
          "cases.diagnoses.primary_diagnosis",
          "cases.project.disease_type",
          "cases.samples.is_ffpe",
          "md5sum",
          "file_size",
          "state",
          "cases.diagnoses.tissue_or_organ_of_origin",
          "cases.diagnoses.morphology",
          "experimental_strategy"]

fields = ",".join(fields)

files_endpt = "https://api.gdc.cancer.gov/files"

# This set of filters is nested under an 'and' operator.
filters = {
    "op": "and",
    "content":[
        {
        "op": "in",
        "content":{
            "field": "cases.project.primary_site",
            "value": ["Lung","Colorectal", "Prostate"]
            }
        },
        {
        "op": "in",
        "content":{
            "field": "files.data_format",
            "value": ["SVS"]
            }
        }
    ]
}
# filters = {
#        "op": "=",
#        "content":{
#             "field": "files.data_format",
#             "value": ["SVS"]
#        }
#     }

# A POST is used, so the filter parameters can be passed directly as a Dict object.
params = {
    "filters": filters,
    "fields": fields,
    "format": "CSV",
    "size": "50000"
    }

# The parameters are passed to 'json' rather than 'params' in this case
response = requests.post(files_endpt, headers = {"Content-Type": "application/json"}, json = params)

# %%
response
# Out:
# <Response [200]>

# %%
urlData = response.content
rawData = pd.read_csv(io.StringIO(urlData.decode('utf-8')), error_bad_lines=False)
print(rawData.shape)
# Out:
# (6364, 14)

# %%
rawData['file_size'].apply(lambda x: x*1e-12).sum()
# Out:
# 2.406884266529

# %%
(rawData["experimental_strategy"].unique())
# Out:
# array(['Tissue Slide', 'Diagnostic Slide'], dtype=object)

# %%
rawData
# Out:
#       cases.0.project.disease_type  cases.0.samples.0.is_ffpe  \
# 0     Lung Squamous Cell Carcinoma                      False
# 1     Lung Squamous Cell Carcinoma                      False
# 2     Lung Squamous Cell Carcinoma                      False
# 3     Lung Squamous Cell Carcinoma                       True
# 4              Lung Adenocarcinoma                      False
# ...                            ...                        ...
# 6359       Prostate Adenocarcinoma                      False
# 6360       Prostate Adenocarcinoma                       True
# 6361       Prostate Adenocarcinoma                       True
# 6362       Prostate Adenocarcinoma                      False
# 6363       Prostate Adenocarcinoma                       True
#
#      cases.0.diagnoses.0.morphology  \
# 0                            8070/3
# 1                            8070/3
# 2                            8070/3
# 3                            8070/3
# 4                            8140/3
# ...                             ...
# 6359                         8140/3
# 6360                         8140/3
# 6361                         8140/3
# 6362                         8140/3
# 6363                         8500/3
#
#                                               file_name  \
# 0     TCGA-77-8153-01A-01-TS1.f808f5c4-36d7-4ef7-ac8...
# 1     TCGA-56-8622-11A-01-TS1.47057b2f-3b19-4f6d-bff...
# 2     TCGA-37-4130-01A-01-TS1.c9786e01-c7e1-4ed3-a2b...
# 3     TCGA-52-7810-01Z-00-DX1.54fcdfff-c1ac-4427-bb3...
# 4     TCGA-49-6767-01A-01-BS1.cf0fa204-1f31-4935-bea...
# ...                                                 ...
# 6359  TCGA-EJ-8472-11A-01-TS1.b0b6f52b-282a-48a7-ba2...
# 6360  TCGA-XJ-A9DI-01Z-00-DX1.0A4BD633-9872-45EC-981...
# 6361  TCGA-EJ-5516-01Z-00-DX1.50003728-b68b-4e22-96d...
# 6362  TCGA-G9-6384-01A-01-BS1.6ce38e25-bc4c-4bf9-9a2...
# 6363  TCGA-VP-A87K-01Z-00-DX1.A1BED19B-7C83-4B88-A86...
#
#                                 md5sum cases.0.diagnoses.0.primary_diagnosis  \
# 0     69f60388d4fa95ea1e09bcda8aea0375          Squamous cell carcinoma, NOS
# 1     44e8644bc086c721c86557d99290b9b7          Squamous cell carcinoma, NOS
# 2     ec273d9f759de29ba62a7bc0af05c336          Squamous cell carcinoma, NOS
# 3     8eecb830331230e7a90c41b22310f48b          Squamous cell carcinoma, NOS
# 4     d4b40349c432636e80e43049eb4341bb                   Adenocarcinoma, NOS
# ...                                ...                                   ...
# 6359  95d6098bef7c74ba779e77a9f4678bf8                   Adenocarcinoma, NOS
# 6360  0eae4bead7e4ebd51eedf6fc526897c6                   Adenocarcinoma, NOS
# 6361  397730c71f4209232c66d70b1c9a8052                   Adenocarcinoma, NOS
# 6362  f59fbbe89ee6bf219fe0edacc8ee43f4                   Adenocarcinoma, NOS
# 6363  7e8863b7ec4c2972cbcde3c814cf91e1      Infiltrating duct carcinoma, NOS
#
#      cases.0.primary_site cases.0.samples.1.is_ffpe     state   file_size  \
# 0       Bronchus and lung                       NaN  released   220927629
# 1       Bronchus and lung                       NaN  released   112296195
# 2       Bronchus and lung                       NaN  released   139886571
# 3       Bronchus and lung                       NaN  released  1028326939
# 4       Bronchus and lung                       NaN  released   176966653
# ...                   ...                       ...       ...         ...
# 6359       Prostate gland                       NaN  released   283658811
# 6360       Prostate gland                       NaN  released   770075443
# 6361       Prostate gland                       NaN  released   545394905
# 6362       Prostate gland                       NaN  released   235103809
# 6363       Prostate gland                       NaN  released   651284064
#
#      cases.0.diagnoses.0.tissue_or_organ_of_origin  \
# 0                                 Lower lobe, lung
# 1                                 Lower lobe, lung
# 2                                 Upper lobe, lung
# 3                       Overlapping lesion of lung
# 4                                Middle lobe, lung
# ...                                            ...
# 6359                                Prostate gland
# 6360                                Prostate gland
# 6361                                Prostate gland
# 6362                                Prostate gland
# 6363                                Prostate gland
#
#                            cases.0.case_id  \
# 0     3336ee77-a6f6-4d3a-93f9-585ebc48ffba
# 1     e731fed6-be23-4b19-8550-6e500613c468
# 2     ac89e063-a288-4516-9d9e-92cc0ed2bc24
# 3     98b86f94-9ede-45ab-ba09-19a6ec6d9494
# 4     6bffe800-ec2b-4638-9333-97fe85dcd91c
# ...                                    ...
# 6359  ab378ad0-1881-403f-9e85-d6f97e7b7c81
# 6360  39a5aebe-acad-4141-aa5a-66228c4049f8
# 6361  1fd06207-54e0-4aba-819c-c7f671871f39
# 6362  a279d5aa-51f7-4e75-9e14-b206b97ec4bd
# 6363  24d7d4d8-f5c1-4d71-80e0-72a429fc9dbd
#
#                                         id experimental_strategy
# 0     e29cb891-954f-4f98-8c62-e67465f67a3c          Tissue Slide
# 1     b3acafb9-7abe-478a-9795-a09d31229f03          Tissue Slide
# 2     5dfcdf0d-eeb2-488f-b1d7-daf063131e62          Tissue Slide
# 3     b5cf01fd-ab75-4a4e-907d-e30d2b263258      Diagnostic Slide
# 4     b984b76a-0fad-4491-a97c-2f198b3e9833          Tissue Slide
# ...                                    ...                   ...
# 6359  292a61c0-2fad-4498-8a5b-18a19434d871          Tissue Slide
# 6360  ae51c4cb-cc6c-4018-a97b-f3a7ae9f9696      Diagnostic Slide
# 6361  7cfaa5d5-a624-469e-bb89-83cca2139dc4      Diagnostic Slide
# 6362  52509164-c0f2-4cdd-b92b-4b9493b9f20f          Tissue Slide
# 6363  7180b8f4-c337-41d3-89ea-144680b5872c      Diagnostic Slide
#
# [6364 rows x 14 columns]

# %%
for col in rawData.columns: 
    print(col)

# %%
rawData.iloc[0].file_name
# Out:
# 'TCGA-77-8153-01A-01-TS1.f808f5c4-36d7-4ef7-ac80-a82b1f8f2ecf.svs'

# %%
rawData.query("file_name == 'TCGA-A6-3810-01B-03-BS3.A7C6B755-37C3-4E01-9FA8-93787D9FB702.svs'")
# Out:
#      cases.0.project.disease_type  cases.0.samples.0.is_ffpe  \
# 3494         Colon Adenocarcinoma                       True
#
#      cases.0.diagnoses.0.morphology  \
# 3494                         8140/3
#
#                                               file_name  \
# 3494  TCGA-A6-3810-01B-03-BS3.A7C6B755-37C3-4E01-9FA...
#
#                                 md5sum cases.0.diagnoses.0.primary_diagnosis  \
# 3494  1aeb0f3d9f76196f218ee3c2137edf6d                   Adenocarcinoma, NOS
#
#      cases.0.primary_site cases.0.samples.1.is_ffpe     state  file_size  \
# 3494                Colon                       NaN  released  199885975
#
#      cases.0.diagnoses.0.tissue_or_organ_of_origin  \
# 3494                                    Colon, NOS
#
#                            cases.0.case_id  \
# 3494  b728e6e8-a0e4-496b-904c-6f07c12e901f
#
#                                         id experimental_strategy
# 3494  e4b21970-ba7d-43e9-a3ea-48bd2710d605          Tissue Slide
